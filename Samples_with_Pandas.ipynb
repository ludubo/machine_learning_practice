# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
df = pd.DataFrame({'nombre': ['Rick', 'Marty'], 'apellidos': ['Sanchez', 'Smith'], 'edad': [60, 14]})
df
# Out:
#   nombre apellidos  edad
# 0   Rick   Sanchez    60
# 1  Marty     Smith    14

# %%
df = pd.DataFrame([['Rick', 'Sanchez', 60], ['Marty', 'Smith', 14]], columns=['nombre', 'apellidos', 'edad'])
df
# Out:
#   nombre apellidos  edad
# 0   Rick   Sanchez    60
# 1  Marty     Smith    14

# %%
data = pd.read_csv("primary_results.csv")
data.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
data.tail(10)
# Out:
#          state state_abbreviation             county        fips       party  \
# 24601  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24602  Wyoming                 WY  Sweetwater-Carbon  95600026.0  Republican
# 24603  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24604  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24605  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24606  Wyoming                 WY     Teton-Sublette  95600028.0  Republican
# 24607  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
# 24608  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
# 24609  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
# 24610  Wyoming                 WY      Uinta-Lincoln  95600027.0  Republican
#
#           candidate  votes  fraction_votes
# 24601   Marco Rubio     28           0.315
# ...

# %%
data.describe()
# Out:
#                fips          votes  fraction_votes
# count  2.451100e+04   24611.000000    24611.000000
# mean   2.667152e+07    2306.252773        0.304524
# std    4.200978e+07    9861.183572        0.231401
# min    1.001000e+03       0.000000        0.000000
# 25%    2.109100e+04      68.000000        0.094000
# 50%    4.208100e+04     358.000000        0.273000
# 75%    9.090012e+07    1375.000000        0.479000
# max    9.560004e+07  590502.000000        1.000000

# %%
data.dtypes
# Out:
# state                  object
# state_abbreviation     object
# county                 object
# fips                  float64
# party                  object
# candidate              object
# votes                   int64
# fraction_votes        float64
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=24611, step=1)

# %%
data2 = data.set_index("county")
data2
# Out:
#                         state state_abbreviation        fips       party  \
# county
# Autauga               Alabama                 AL      1001.0    Democrat
# Autauga               Alabama                 AL      1001.0    Democrat
# Baldwin               Alabama                 AL      1003.0    Democrat
# Baldwin               Alabama                 AL      1003.0    Democrat
# Barbour               Alabama                 AL      1005.0    Democrat
# Barbour               Alabama                 AL      1005.0    Democrat
# Bibb                  Alabama                 AL      1007.0    Democrat
# Bibb                  Alabama                 AL      1007.0    Democrat
# Blount                Alabama                 AL      1009.0    Democrat
# Blount                Alabama                 AL      1009.0    Democrat
# Bullock               Alabama                 AL      1011.0    Democrat
# Bullock               Alabama                 AL      1011.0    Democrat
# ...

# %% [markdown]
# Seek in column index

# %%
data2.loc["Laramie"]
# Out:
#            state state_abbreviation        fips       party        candidate  \
# county
# Laramie  Wyoming                 WY     56021.0    Democrat   Bernie Sanders
# Laramie  Wyoming                 WY     56021.0    Democrat  Hillary Clinton
# Laramie  Wyoming                 WY  95600036.0  Republican     Donald Trump
# Laramie  Wyoming                 WY  95600036.0  Republican      John Kasich
# Laramie  Wyoming                 WY  95600036.0  Republican      Marco Rubio
# Laramie  Wyoming                 WY  95600036.0  Republican         Ted Cruz
#
#          votes  fraction_votes
# county
# Laramie     25           0.490
# Laramie     26           0.510
# Laramie      0           0.000
# Laramie      0           0.000
# Laramie     38           0.176
# Laramie    141           0.653

# %%
Seek specific row in index

# %%
data2.iloc[2]
# Out:
# state                        Alabama
# state_abbreviation                AL
# fips                            1003
# party                       Democrat
# candidate             Bernie Sanders
# votes                           2694
# fraction_votes                 0.329
# Name: Baldwin, dtype: object

# %%
data2["state"]
# Out:
# county
# Autauga                 Alabama
# Autauga                 Alabama
# Baldwin                 Alabama
# Baldwin                 Alabama
# Barbour                 Alabama
# Barbour                 Alabama
# Bibb                    Alabama
# Bibb                    Alabama
# Blount                  Alabama
# Blount                  Alabama
# Bullock                 Alabama
# Bullock                 Alabama
# Butler                  Alabama
# Butler                  Alabama
# Calhoun                 Alabama
# Calhoun                 Alabama
# Chambers                Alabama
# Chambers                Alabama
# Cherokee                Alabama
# Cherokee                Alabama
# Chilton                 Alabama
# Chilton                 Alabama
# Choctaw                 Alabama
# Choctaw                 Alabama
# Clarke                  Alabama
# Clarke                  Alabama
# Clay                    Alabama
# Clay                    Alabama
# Cleburne                Alabama
# ...

# %%
data2["new_column"] = 3

# %%
data2.head()
# Out:
#            state state_abbreviation    fips     party        candidate  votes  \
# county
# Autauga  Alabama                 AL  1001.0  Democrat   Bernie Sanders    544
# Autauga  Alabama                 AL  1001.0  Democrat  Hillary Clinton   2387
# Baldwin  Alabama                 AL  1003.0  Democrat   Bernie Sanders   2694
# Baldwin  Alabama                 AL  1003.0  Democrat  Hillary Clinton   5290
# Barbour  Alabama                 AL  1005.0  Democrat   Bernie Sanders    222
#
#          fraction_votes  new_column
# county
# Autauga           0.182           3
# Autauga           0.800           3
# Baldwin           0.329           3
# Baldwin           0.647           3
# Barbour           0.078           3

# %% [markdown]
# Filtering for values in a column

# %%
data2[data2.votes> 500000]
# Out:
#                   state state_abbreviation    fips     party        candidate  \
# county
# Los Angeles  California                 CA  6037.0  Democrat  Hillary Clinton
#
#               votes  fraction_votes  new_column
# county
# Los Angeles  590502            0.57           3

# %% [markdown]
# Filtering with 2 columns

# %%
data2[(data2.party == "Democrat") & (data2.votes >200000)]
# Out:
#                      state state_abbreviation        fips     party  \
# county
# Los Angeles     California                 CA      6037.0  Democrat
# Los Angeles     California                 CA      6037.0  Democrat
# Chicago           Illinois                 IL  91700103.0  Democrat
# Chicago           Illinois                 IL  91700103.0  Democrat
# Cook Suburbs      Illinois                 IL  91700104.0  Democrat
# Cook Suburbs      Illinois                 IL  91700104.0  Democrat
# Philadelphia  Pennsylvania                 PA     42101.0  Democrat
#
#                     candidate   votes  fraction_votes  new_column
# county
# Los Angeles    Bernie Sanders  434656           0.420           3
# Los Angeles   Hillary Clinton  590502           0.570           3
# Chicago        Bernie Sanders  311225           0.454           3
# Chicago       Hillary Clinton  366954           0.536           3
# Cook Suburbs   Bernie Sanders  212428           0.457           3
# ...

# %%
county1 = "Chicago"
county1
numvotes = 5000
#data2[data2.votes > @numvotes]
data2.query("votes > @numvotes")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-b8db6655de03> in <module>
#       3 numvotes = 5000
#       4 #data2[data2.votes > @numvotes]
# ----> 5 data2.query("votes > @numvotes")
#
# TypeError: 'str' object is not callable
